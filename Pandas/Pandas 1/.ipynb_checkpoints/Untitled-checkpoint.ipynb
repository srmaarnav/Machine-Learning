# %% [markdown]
# Loading data in pandas

# %%
import pandas as pd

df = pd.read_csv('Pokemon.csv')

# df = pd.read_excel   //for excel

# df = pd.read_csv('pokemon.txt', delimiter='\t')  //for tab seperated data files in txt form   //delimiter works as what to seperate data

# print (df.head(3))

# print (df.tail(3))

# %% [markdown]
# Reading Data In pandas

# %%
### read header
print(df.columns)
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
### for each column reading
df.columns
print(df['Name'])

# for multiple columns
# print(df[['Name'], ['Type 1'], ['HP']])

# also works
# print(df.Name)

# print(df['Name'][0:5])
# gives only first five columns
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %%
###read each specific row
# print(df.iloc[1])

# for multiple rows
print(df.iloc[0:4])
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False

# %%
##for specific row and column (R, C)

print(df.iloc[2,1])
# Out:
# Venusaur

# %%
# for index, row in df.iterrows():
#     print(index, row)

# for index, row in df.iterrows():
#     print(index, row['HP'])

# %%
# for specific condition

df.loc[df['Type 1'] == 'Grass']
# Out:
#        #                   Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 0      1              Bulbasaur  Grass    Poison    318   45      49       49
# 1      2                Ivysaur  Grass    Poison    405   60      62       63
# 2      3               Venusaur  Grass    Poison    525   80      82       83
# 3      3  VenusaurMega Venusaur  Grass    Poison    625   80     100      123
# 48    43                 Oddish  Grass    Poison    320   45      50       55
# ..   ...                    ...    ...       ...    ...  ...     ...      ...
# 718  650                Chespin  Grass       NaN    313   56      61       65
# 719  651              Quilladin  Grass       NaN    405   61      78       95
# 720  652             Chesnaught  Grass  Fighting    530   88     107      122
# 740  672                 Skiddo  Grass       NaN    350   66      65       48
# 741  673                 Gogoat  Grass       NaN    531  123     100       62
#
# ...

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
# sorting

# df.sort_values('Name', ascending=False)

# df.sort_values(['Type 1', 'HP'], ascending=False)

df.sort_values(['Type 1', 'HP'], ascending=[1, 0])
# makes type 1 go from a to z and hp from high to low
# Out:
#        #                     Name Type 1    Type 2  Total  HP  Attack  \
# 520  469                  Yanmega    Bug    Flying    515  86      76
# 698  637                Volcarona    Bug      Fire    550  85      60
# 231  214                Heracross    Bug  Fighting    500  80     125
# 232  214  HeracrossMega Heracross    Bug  Fighting    600  80     185
# 678  617                 Accelgor    Bug       NaN    495  80      70
# ..   ...                      ...    ...       ...    ...  ..     ...
# 106   98                   Krabby  Water       NaN    325  30     105
# 125  116                   Horsea  Water       NaN    295  30      40
# 129  120                   Staryu  Water       NaN    340  30      45
# 139  129                 Magikarp  Water       NaN    200  20      10
# 381  349                   Feebas  Water       NaN    200  20      15
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 520       86      116       56     95           4      False
# ...

# %% [markdown]
# Making CHanges to data

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
# df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
# df = df.drop(columns = ['Total'])

df['Total'] = df.iloc[:,4:10].sum(axis=1)

# end parameter in list is exclusive, 10 means 10th column is the one we dont include
# iloc[all rows, list of columns].sum(axis=1(horizaontally), axis=0(vertically)]



df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    591  45      49       49
# 1  2                Ivysaur  Grass  Poison    750  60      62       63
# 2  3               Venusaur  Grass  Poison    970  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison   1170  80     100      123
# 4  4             Charmander   Fire     NaN    553  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# Saving to external

# %%
# df.to_csv('modified.csv', index=False)

# df.to_excel('modified.xlsx', index=False)

df.to_csv('modified.txt', index=False, sep='\t')

# %% [markdown]
# Filtering of data

# %%
new_df = df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] > 50)]

new_df.to_csv('modfied1.csv')

# %% [markdown]
# after shrinking a data into new dataset, the index is damaged

# %% [markdown]
# Reset Index

# %%
new_df = new_df.reset_index()
new_df
# Out:
#    index    #                   Name Type 1  Type 2  Total   HP  Attack  \
# 0      1    2                Ivysaur  Grass  Poison    750   60      62
# 1      2    3               Venusaur  Grass  Poison    970   80      82
# 2      3    3  VenusaurMega Venusaur  Grass  Poison   1170   80     100
# 3     49   44                  Gloom  Grass  Poison    750   60      65
# 4     50   45              Vileplume  Grass  Poison    930   75      80
# 5     76   70             Weepinbell  Grass  Poison    725   65      90
# 6     77   71             Victreebel  Grass  Poison    910   80     105
# 7    452  407               Roserade  Grass  Poison    940   60      70
# 8    651  590                Foongus  Grass  Poison    573   69      55
# 9    652  591              Amoonguss  Grass  Poison    898  114      85
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       63       80       80     60           1      False
# ...

# %%
new_df1 = new_df

# %%
new_df1
# Out:
#    index    #                   Name Type 1  Type 2  Total   HP  Attack  \
# 0      1    2                Ivysaur  Grass  Poison    750   60      62
# 1      2    3               Venusaur  Grass  Poison    970   80      82
# 2      3    3  VenusaurMega Venusaur  Grass  Poison   1170   80     100
# 3     49   44                  Gloom  Grass  Poison    750   60      65
# 4     50   45              Vileplume  Grass  Poison    930   75      80
# 5     76   70             Weepinbell  Grass  Poison    725   65      90
# 6     77   71             Victreebel  Grass  Poison    910   80     105
# 7    452  407               Roserade  Grass  Poison    940   60      70
# 8    651  590                Foongus  Grass  Poison    573   69      55
# 9    652  591              Amoonguss  Grass  Poison    898  114      85
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       63       80       80     60           1      False
# ...

# %%
new_df1 = new_df1.reset_index(drop=True)
new_df1
# Out:
#    index    #                   Name Type 1  Type 2  Total   HP  Attack  \
# 0      1    2                Ivysaur  Grass  Poison    750   60      62
# 1      2    3               Venusaur  Grass  Poison    970   80      82
# 2      3    3  VenusaurMega Venusaur  Grass  Poison   1170   80     100
# 3     49   44                  Gloom  Grass  Poison    750   60      65
# 4     50   45              Vileplume  Grass  Poison    930   75      80
# 5     76   70             Weepinbell  Grass  Poison    725   65      90
# 6     77   71             Victreebel  Grass  Poison    910   80     105
# 7    452  407               Roserade  Grass  Poison    940   60      70
# 8    651  590                Foongus  Grass  Poison    573   69      55
# 9    652  591              Amoonguss  Grass  Poison    898  114      85
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       63       80       80     60           1      False
# ...

# %% [markdown]
# Regex filter ( textual patterns)

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#        #                       Name    Type 1    Type 2  Total   HP  Attack  \
# 3      3      VenusaurMega Venusaur     Grass    Poison   1170   80     100
# 7      6  CharizardMega Charizard X      Fire    Dragon   1168   78     130
# 8      6  CharizardMega Charizard Y      Fire    Flying   1168   78     104
# 12     9    BlastoiseMega Blastoise     Water       NaN   1182   79     103
# 19    15      BeedrillMega Beedrill       Bug    Poison    845   65     150
# 23    18        PidgeotMega Pidgeot    Normal    Flying   1037   83      80
# 71    65      AlakazamMega Alakazam   Psychic       NaN   1030   55      50
# 87    80        SlowbroMega Slowbro     Water   Psychic   1150   95      75
# 102   94          GengarMega Gengar     Ghost    Poison   1070   60      65
# 124  115  KangaskhanMega Kangaskhan    Normal       NaN   1080  105     125
# 137  127          PinsirMega Pinsir       Bug    Flying   1095   65     155
# ...

# %%
df.loc[~df['Name'].str.contains('Mega')]
# not containing mega
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 0      1            Bulbasaur    Grass  Poison    591   45      49       49
# 1      2              Ivysaur    Grass  Poison    750   60      62       63
# 2      3             Venusaur    Grass  Poison    970   80      82       83
# 4      4           Charmander     Fire     NaN    553   39      52       43
# 5      5           Charmeleon     Fire     NaN    730   58      64       58
# ..   ...                  ...      ...     ...    ...  ...     ...      ...
# 794  718     Zygarde50% Forme   Dragon  Ground   1105  108     100      121
# 795  719              Diancie     Rock   Fairy   1150   50     100      150
# 797  720  HoopaHoopa Confined  Psychic   Ghost   1130   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark   1280   80     160       60
# 799  721            Volcanion     Fire   Water   1130   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
import re

# df.loc[df['Type 1'].str.contains('Fire|Grass', regex=True)]
# this needs capitalization

# df.loc[df['Type 1'].str.contains('fire|grass', flags = re.I, regex=True)]
# flags = re.I removes need of exact capitalization in the result

# df.loc[df['Name'].str.contains('Pi[a-z]*', flags = re.I, regex=True)]
df.loc[df['Name'].str.contains('^Pi[a-z]*', flags = re.I, regex=True)]
# Out:
#        #                 Name    Type 1    Type 2  Total   HP  Attack  \
# 20    16               Pidgey    Normal    Flying    446   40      45
# 21    17            Pidgeotto    Normal    Flying    627   63      60
# 22    18              Pidgeot    Normal    Flying    857   83      80
# 23    18  PidgeotMega Pidgeot    Normal    Flying   1037   83      80
# 30    25              Pikachu  Electric       NaN    550   35      55
# 136  127               Pinsir       Bug       NaN    915   65     125
# 137  127    PinsirMega Pinsir       Bug    Flying   1095   65     155
# 186  172                Pichu  Electric       NaN    350   20      40
# 219  204               Pineco       Bug       NaN    565   50      65
# 239  221            Piloswine       Ice    Ground    850  100     100
# 438  393               Piplup     Water       NaN    588   53      51
# 558  499              Pignite      Fire  Fighting    781   90      93
# ...

# %% [markdown]
# Conditional Changes

# %%
# df.loc[df['Type 1'] == 'Fire' , 'Type 1'] = 'Flamer'

# df

df.loc[df['Type 1'] == 'Flamer' , 'Type 1'] = 'Fire'

df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    591  45      49       49
# 1      2                Ivysaur    Grass  Poison    750  60      62       63
# 2      3               Venusaur    Grass  Poison    970  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison   1170  80     100      123
# 4      4             Charmander     Fire     NaN    553  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy   1150  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy   1290  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost   1130  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark   1280  80     160       60
# 799  721              Volcanion     Fire   Water   1130  80     110      120
#
# ...

# %% [markdown]
# Aggregate Statistics (Group By)

# %%
df.groupby(['Type 1']).mean().sort_values('Defense', ascending=False)
# Out:
#                    #        Total         HP      Attack     Defense  \
# Type 1
# Steel     442.851852   920.148148  65.222222   92.703704  126.370370
# Rock      392.727273   851.590909  65.363636   92.863636  100.795455
# Dragon    474.375000  1018.031250  83.312500  112.125000   86.375000
# Ground    356.281250   811.093750  73.781250   95.750000   84.843750
# Ghost     486.500000   814.781250  64.437500   73.781250   81.187500
# Water     303.089286   794.946429  72.062500   74.151786   72.946429
# Ice       423.541667   803.458333  72.000000   72.750000   71.416667
# Grass     344.871429   780.357143  67.271429   73.214286   70.800000
# Bug       334.492754   696.173913  56.884058   70.971014   70.724638
# Dark      461.354839   815.322581  66.806452   88.387097   70.225806
# Poison    251.785714   734.714286  67.250000   74.678571   68.821429
# Fire      327.403846   841.711538  69.903846   84.769231   67.769231
# ...

# %%
# df.groupby(['Type 1']).mean().sort_values('Attack', ascending=False)
# df.groupby(['Type 1']).mean().sort_values('HP', ascending=False)
df.groupby(['Type 1']).mean().sort_values('Speed', ascending=False)
# Out:
#                    #        Total         HP      Attack     Defense  \
# Type 1
# Flying    677.750000   867.500000  70.750000   78.750000   66.250000
# Electric  363.500000   802.318182  59.795455   69.090909   66.295455
# Dragon    474.375000  1018.031250  83.312500  112.125000   86.375000
# Psychic   380.807018   870.403509  70.631579   71.456140   67.684211
# Dark      461.354839   815.322581  66.806452   88.387097   70.225806
# Fire      327.403846   841.711538  69.903846   84.769231   67.769231
# Normal    319.173469   731.816327  77.275510   73.469388   59.846939
# Fighting  363.851852   766.814815  69.851852   96.777778   65.925926
# Water     303.089286   794.946429  72.062500   74.151786   72.946429
# Ghost     486.500000   814.781250  64.437500   73.781250   81.187500
# Ground    356.281250   811.093750  73.781250   95.750000   84.843750
# Poison    251.785714   734.714286  67.250000   74.678571   68.821429
# ...

# %%
df.groupby(['Type 1']).sum()
# Out:
#               #  Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Type 1
# Bug       23080  48036  3925    4897     4880     3717     4471   4256
# Dark      14302  25275  2071    2740     2177     2314     2155   2361
# Dragon    15180  32577  2666    3588     2764     3099     2843   2657
# Electric  15994  35302  2631    3040     2917     3961     3243   3718
# Fairy      7642  13222  1260    1046     1117     1335     1440    826
# Fighting   9824  20704  1886    2613     1780     1434     1747   1784
# Fire      17025  43769  3635    4408     3524     4627     3755   3871
# Flying     2711   3470   283     315      265      377      290    410
# Ghost     15568  26073  2062    2361     2598     2539     2447   2059
# Grass     24141  54625  4709    5125     4956     5425     4930   4335
# Ground    11401  25955  2361    3064     2715     1807     2008   2045
# Ice       10165  19283  1728    1746     1714     1861     1831   1523
# ...

# %%
# df.groupby(['Type 1']).count()
df['count']=1
df.groupby(['Type 1', 'Type 2']).count()['count']
# Out:
# Type 1  Type 2
# Bug     Electric     2
#         Fighting     2
#         Fire         2
#         Flying      14
#         Ghost        1
#                     ..
# Water   Ice          3
#         Poison       3
#         Psychic      5
#         Rock         4
#         Steel        1
# Name: count, Length: 136, dtype: int64
